# %%
import pickle
with open('output_with_embeddings.pkl', "rb") as f:
    data = pickle.load(f)

print(data["nodes"][0])
# Iterate through each node and delete the 'name' key from 'features'
for node in data["nodes"]:
    if "features" in node and "name" in node["features"]:
        del node["features"]["name"]
# Out:
# {'id': 'CVE-1999-0001', 'type': 'CVE', 'features': {'description_embedding': [-0.1116778776049614, -0.056223951280117035, -0.09917078912258148, -0.03130057081580162, 0.26885631680488586, -0.36346814036369324, 0.1445944905281067, 0.3967161476612091, -0.2117941826581955, 0.16022253036499023, -0.2760400176048279, -0.5792508125305176, -0.45407241582870483, 0.4055813252925873, -0.024282529950141907, 0.35036346316337585, -0.007183936890214682, 0.16562725603580475, -0.034193750470876694, 0.17400556802749634, 0.01985287293791771, 0.06337489187717438, -0.38605719804763794, 0.2451535314321518, 0.32471293210983276, 0.06748273223638535, -0.038977060467004776, -0.03115934692323208, -0.7731578350067139, -0.2712545394897461, 0.18066544830799103, 0.01740659400820732, 0.19286076724529266, -0.1829635053873062, -0.07231318950653076, 0.09781153500080109, 0.03869049623608589, -0.3927799165248871, -0.11484263092279434, 0.2643766701221466, -0.5475997924804688, -0.8020403385162354, 0.3719238340854645, 0.118
# ...
